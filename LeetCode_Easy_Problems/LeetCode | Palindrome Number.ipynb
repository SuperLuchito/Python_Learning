# %%
# My Solution | Runtime: 13 ms, Beats 41.29% | Memory: 12.36 MB, Beats 81.39%

x = 121

def isPalindrome(x):
    return str(x) == str(x)[::-1]

isPalindrome(x)
# Out:
# True

# %%
# Solution of AI (Gemeni 2.5 Pro) | Runtime: 8 ms, Beats 69.69% | Memory: 12.55 MB, Beats 10.56%

def is_palindrome(x):
    if x < 0:
        return False
    return str(x) == str(x)[::-1]

input_x = 121
expected_output = True

is_palindrome(input_x)
# Out:
# True
